# %%
# %load_ext autoreload
# %autoreload 2

# %%
from data.bt_dataset import BrainTumorDataset
from model2 import BrainTumorCNN
from torch.utils.data import DataLoader, Subset
import torchvision
from torchvision import transforms
import torch
import os
import cv2
from data.preprocessing import *
from train import train
from evaluate import evaluate
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available():
    print("Working on: GPU")
    device = 'cuda'
else:
    print("Working on: CPU")
    device = 'cpu'
# Out:
# Working on: GPU

# %% [markdown]
# ### Defining constants:

# %%
IMAGE_SIZE = 256
NUM_OF_CLASSES = 4
train_batch_size = test_batch_size = 32
dataset_path = os.path.join(os.getcwd(), 'data')

# %% [markdown]
# ### Preprocessing:

# %%
# Resizing the images and sharpening them:
preprocessing_ops = [denoise(), normalize(), resize([IMAGE_SIZE, IMAGE_SIZE]), sharpen()]
preprocessing_ops = [resize([IMAGE_SIZE, IMAGE_SIZE]), sharpen()]
image_preprocessing = transforms.Compose([
                                        transforms.ToTensor(),
                                        transforms.transforms.Normalize((0.16, 0.16, 0.16), (0.18,  0.18, 0.18)),
                                        transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
                                        lambda image : transforms.functional.adjust_sharpness(image, sharpness_factor=2) 
                                        ])

# %% [markdown]
# ### Defining the dataset:

# %%
# Defining the Dataset object:
demo_dataset = BrainTumorDataset(dataset_path=dataset_path, preprocessing=None)
dataset = BrainTumorDataset(dataset_path=dataset_path, preprocessing=image_preprocessing)

# Defining the DataLoader object:
train_loader = DataLoader(dataset, batch_size=train_batch_size)

# %%
dataset.get_data_distribution()
# Out:
# {'pituitary_tumor': 827,
#  'glioma_tumor': 826,
#  'meningioma_tumor': 822,
#  'no_tumor': 395}

# %% [markdown]
# ### Plotting a sample image

# %%
pre_processed_img = dataset[0][0]
original_image = demo_dataset[0][0]

# %%
f, axarr = plt.subplots(1,2)

axarr[0].imshow(pre_processed_img.permute(1, 2, 0))
axarr[1].imshow(original_image.permute(0, 1, 2))

# %% [markdown]
# ### Model specifications:

# %%
model = BrainTumorCNN(number_of_classes=NUM_OF_CLASSES, image_size=IMAGE_SIZE)

parameters = model.parameters()
learning_rate = 1e-4
weight_decay = 2e-7
momentum = 0.9

# Getting the class weights to apply weighted loss:
class_weights = torch.tensor(dataset.class_weights).float().to(device)
criterion = torch.nn.CrossEntropyLoss(weight=class_weights).to(device)
optimizer = torch.optim.SGD(parameters, lr=learning_rate, momentum=momentum, weight_decay=weight_decay)

# %%
scheduler = StepLR(optimizer, step_size=5, gamma=1.2)

# %%
sample_size = 10
overfitting_set = []
class_indicies_distrib = dataset.class_indicies_distribution()
for i in class_indicies_distrib:
    overfitting_set += class_indicies_distrib[i][:10]

# %% [markdown]
# ## Overfitting the model in order to test if it can learn

# %%
overfitting_subset = Subset(dataset, overfitting_set)
overfitting_loader = DataLoader(overfitting_subset)

# %%
epochs = 10

# %%
scheduler = None
total_loss, epoch_times, accuracies_train, _ = train(model=model, train_loader=overfitting_loader,
                                                                   test_loader=overfitting_loader, optimizer=optimizer,
                                                                   criterion=criterion, epochs=epochs, scheduler=scheduler)
# Out:
# 100%|██████████| 40/40 [00:05<00:00,  7.60it/s]
# Evaluating epoch...
# Epoch: 0 | Loss: 98.29
# Epoch: 0 took: 9.88 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.60it/s]
# Evaluating epoch...
# Epoch: 1 | Loss: 63.71
# Epoch: 1 took: 15.93 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.18it/s]
# Evaluating epoch...
# Epoch: 2 | Loss: 59.37
# Epoch: 2 took: 16.20 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.19it/s]
# Evaluating epoch...
# Epoch: 3 | Loss: 58.06
# Epoch: 3 took: 16.22 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.09it/s]
# Evaluating epoch...
# Epoch: 4 | Loss: 57.37
# Epoch: 4 took: 10.26 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.74it/s]
# Evaluating epoch...
# Epoch: 5 | Loss: 56.85
# Epoch: 5 took: 12.64 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.30it/s]
# Evaluating epoch...
# Epoch: 6 | Loss: 56.40
# Epoch: 6 took: 16.27 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.55it/s]
# Evaluating epoch...
# Epoch: 7 | Loss: 55.99
# Epoch: 7 took: 9.13 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.37it/s]
# Evaluating epoch...
# Epoch: 8 | Loss: 55.59
# Epoch: 8 took: 16.06 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.22it/s]
# Evaluating epoch...
# Epoch: 9 | Loss: 55.19
# Epoch: 9 took: 9.96 seconds
# 100%|██████████| 40/40 [00:00<00:00, 91.70it/s]
# Evaluating epoch...
# Epoch: 10 | Loss: 54.80
# Epoch: 10 took: 4.92 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.39it/s]
# Evaluating epoch...
# Epoch: 11 | Loss: 54.40
# Epoch: 11 took: 16.10 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.25it/s]
# Evaluating epoch...
# Epoch: 12 | Loss: 53.98
# Epoch: 12 took: 10.89 seconds
# 100%|██████████| 40/40 [00:02<00:00, 13.51it/s]
# Evaluating epoch...
# Epoch: 13 | Loss: 53.60
# Epoch: 13 took: 13.61 seconds
# 100%|██████████| 40/40 [00:05<00:00,  7.22it/s]
# Evaluating epoch...
# Epoch: 14 | Loss: 53.12
# Epoch: 14 took: 16.40 seconds

# %% [markdown]
# ### Plotting the loss:

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(total_loss)
plt.show()

# %% [markdown]
# ### Plotting train accuracy:

# %%
plt.plot(accuracies_train)
plt.show()

# %%
accuracy = evaluate(model=model, test_loader=overfitting_loader)
print(f'Overfitting Accuracy: {accuracy:.2f}%')
# Out:
# Overfitting Accuracy: 85.00%

# %% [markdown]
# ### Creating the model to train it

# %%
model = BrainTumorCNN(number_of_classes=NUM_OF_CLASSES, image_size=IMAGE_SIZE)

parameters = model.parameters()
learning_rate = 1e-4
weight_decay = 2e-4
momentum = 0.9

# Getting the class weights to apply weighted loss:
class_weights = torch.tensor(dataset.class_weights).float().to(device)
criterion = torch.nn.CrossEntropyLoss(weight=class_weights).to(device)
optimizer = torch.optim.SGD(parameters, lr=learning_rate, momentum=momentum, weight_decay=weight_decay)

# %%
scheduler = StepLR(optimizer, step_size=5, gamma=1.1)

# %% [markdown]
# ### Training the model

# %%
# Defining the Dataset object:
test_dataset = BrainTumorDataset(dataset_path=dataset_path, preprocessing=image_preprocessing, test=True)
train_dataset = BrainTumorDataset(dataset_path=dataset_path, preprocessing=image_preprocessing, test=False)

# Defining the DataLoader object:
test_loader = DataLoader(test_dataset, batch_size=train_batch_size)
train_loader = DataLoader(train_dataset, batch_size=train_batch_size)

# %%
scheduler = StepLR(optimizer, step_size=2, gamma=1.2)

# %%
epochs = 50

# %%
scheduler = None
total_loss, epoch_times, accuracies_train, accuracies_test = train(model=model, train_loader=train_loader,
                                                                   test_loader=test_loader, optimizer=optimizer,
                                                                   criterion=criterion, epochs=epochs, scheduler=scheduler)
# Out:
# 100%|██████████| 90/90 [02:31<00:00,  1.68s/it]
# Evaluating epoch...
# Epoch: 0 | Loss: 196.37
# Epoch: 0 took: 344.83 seconds
# 100%|██████████| 90/90 [00:39<00:00,  2.29it/s]
# Evaluating epoch...
# Epoch: 1 | Loss: 145.96
# Epoch: 1 took: 243.01 seconds
# 100%|██████████| 90/90 [00:58<00:00,  1.54it/s]
# Evaluating epoch...
# Epoch: 2 | Loss: 129.75
# Epoch: 2 took: 255.97 seconds
# 100%|██████████| 90/90 [02:13<00:00,  1.48s/it]
# Evaluating epoch...
# Epoch: 3 | Loss: 126.93
# Epoch: 3 took: 335.41 seconds
# 100%|██████████| 90/90 [02:29<00:00,  1.66s/it]
# Evaluating epoch...
# Epoch: 4 | Loss: 125.75
# Epoch: 4 took: 208.75 seconds
# 100%|██████████| 90/90 [00:21<00:00,  4.25it/s]
# Evaluating epoch...
# Epoch: 5 | Loss: 125.07
# Epoch: 5 took: 44.74 seconds
# 100%|██████████| 90/90 [00:21<00:00,  4.28it/s]
# Evaluating epoch...
# Epoch: 6 | Loss: 124.62
# Epoch: 6 took: 129.24 seconds
# 100%|██████████| 90/90 [00:20<00:00,  4.30it/s]
# Evaluating epoch...
# Epoch: 7 | Loss: 124.30
# Epoch: 7 took: 43.59 seconds
# 100%|██████████| 90/90 [01:06<00:00,  1.35it/s]
# Evaluating epoch...
# Epoch: 8 | Loss: 124.00
# Epoch: 8 took: 89.62 seconds
# 100%|██████████| 90/90 [00:20<00:00,  4.35it/s]
# Evaluating epoch...
# Epoch: 9 | Loss: 123.79
# Epoch: 9 took: 82.37 seconds
# 100%|██████████| 90/90 [00:20<00:00,  4.37it/s]
# Evaluating epoch...
# Epoch: 10 | Loss: 123.55
# Epoch: 10 took: 43.35 seconds
# 100%|██████████| 90/90 [00:20<00:00,  4.37it/s]
# Evaluating epoch...
# Epoch: 11 | Loss: 123.35
# Epoch: 11 took: 98.28 seconds
# 100%|██████████| 90/90 [00:20<00:00,  4.33it/s]
# Evaluating epoch...
# Epoch: 12 | Loss: 123.14
# Epoch: 12 took: 71.35 seconds
#   0%|          | 0/90 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-137152b7192b> in <module>()
#       2 total_loss, epoch_times, accuracies_train, accuracies_test = train(model=model, train_loader=train_loader,
#       3                                                                    test_loader=test_loader, optimizer=optimizer,
# ----> 4                                                                    criterion=criterion, epochs=epochs, scheduler=scheduler)
#
# /scratch/users/ahamadeh18/COMP448/BrainTumorClassificationCNN/train.py in train(model, train_loader, test_loader, optimizer, criterion, epochs, scheduler)
#      18         epoch_loss = 0
#      19         epoch_tic = time.time()
# ---> 20         for x, y, _ in tqdm(train_loader):
#      21
#      22             optimizer.zero_grad()
#
# ~/.local/lib/python3.6/site-packages/tqdm/std.py in __iter__(self)
#    1193
#    1194         try:
# -> 1195             for obj in iterable:
#    1196                 yield obj
#    1197                 # Update and possibly print the progressbar.
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# ~/.local/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /scratch/users/ahamadeh18/COMP448/BrainTumorClassificationCNN/data/bt_dataset.py in __getitem__(self, index)
#     112         image_label_txt = self.data_labels_txt[index]
#     113         if self.preprocessing != None:
# --> 114             image = self.preprocessing(image)
#     115         else:
#     116              image = torch.tensor(image)
#
# ~/.local/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      59     def __call__(self, img):
#      60         for t in self.transforms:
# ---> 61             img = t(img)
#      62         return img
#      63
#
# ~/.local/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      96             Tensor: Converted image.
#      97         """
# ---> 98         return F.to_tensor(pic)
#      99
#     100     def __repr__(self):
#
# ~/.local/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#     127         # backward compatibility
#     128         if isinstance(img, torch.ByteTensor):
# --> 129             return img.to(dtype=default_float_dtype).div(255)
#     130         else:
#     131             return img
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plotting the loss:

# %%
plt.plot(total_loss)
plt.show()

# %% [markdown]
# ### Plotting train and test accuracies:

# %%
plt.plot(accuracies_train)
plt.plot(accuracies_test)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-974a45ef83e2> in <module>()
#       1 plt.plot(accuracies_train)
# ----> 2 plt.plot(accuracies_test)
#       3 plt.show()
#
# NameError: name 'accuracies_test' is not defined

# %% [markdown]
# ### Evaluating the model:

# %%
accuracy = evaluate(model=model, test_loader=test_loader)

# %%
print(f'Test Accuracy: {accuracy:.2f}%')
# Out:
# Test Accuracy: 34.86%

# %%
accuracy = evaluate(model=model, test_loader=train_loader)

# %%
print(f'Train Accuracy: {accuracy:.2f}%')
# Out:
# Train Accuracy: 76.98%
